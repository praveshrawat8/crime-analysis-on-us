# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
us_df=pd.read_csv("C:\\Users\\Mahesh\\Desktop\\pravesh\\project\\crime analysis on us\\report.csv")
us_df
# Out:
#       report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 0            1975     NM00101     Albuquerque, NM    286238.0          2383.0
# 1            1976     NM00101     Albuquerque, NM    292265.0          2420.0
# 2            1977     NM00101     Albuquerque, NM    292341.0          2390.0
# 3            1978     NM00101     Albuquerque, NM    291834.0          2434.0
# 4            1979     NM00101     Albuquerque, NM    302120.0          2679.0
# ...           ...         ...                 ...         ...             ...
# 2783         2011     KS08703         Wichita, KS    384796.0          2963.0
# 2784         2012     KS08703         Wichita, KS    386409.0          2896.0
# 2785         2013     KS08703         Wichita, KS    386486.0          3069.0
# 2786         2014     KS08703         Wichita, KS    387493.0          2939.0
# 2787         2015     KS08703         Wichita, KS    389824.0          3839.0
#
#       homicides  rapes  assaults  robberies  months_reported  \
# 0          30.0  181.0    1353.0      819.0             12.0
# 1          28.0  186.0    1335.0      871.0             12.0
# 2          31.0  207.0    1398.0      754.0             12.0
# 3          37.0  187.0    1516.0      694.0             12.0
# 4          47.0  215.0    1602.0      815.0             12.0
# ...         ...    ...       ...        ...              ...
# 2783       25.0  245.0    2203.0      490.0             12.0
# 2784       23.0  242.0    2135.0      496.0             12.0
# 2785       15.0  250.0    2337.0      467.0             12.0
# 2786       21.0  243.0    2179.0      496.0             12.0
# 2787       27.0  349.0    2730.0      733.0              NaN
#
#       crimes_percapita  homicides_percapita  rapes_percapita  \
# 0               832.52                10.48            63.23
# 1               828.02                 9.58            63.64
# 2               817.54                10.60            70.81
# 3               834.04                12.68            64.08
# 4               886.73                15.56            71.16
# ...                ...                  ...              ...
# 2783            770.02                 6.50            63.67
# 2784            749.46                 5.95            62.63
# 2785            794.08                 3.88            64.69
# 2786            758.47                 5.42            62.71
# 2787            984.80                 6.93            89.53
#
#       assaults_percapita  robberies_percapita
# 0                 472.68               286.13
# 1                 456.78               298.02
# 2                 478.21               257.92
# 3                 519.47               237.81
# 4                 530.25               269.76
# ...                  ...                  ...
# 2783              572.51               127.34
# 2784              552.52               128.36
# 2785              604.68               120.83
# 2786              562.33               128.00
# 2787              700.32               188.03
#
# [2788 rows x 15 columns]

# %%
us_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2788 entries, 0 to 2787
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   report_year          2788 non-null   int64
#  1   agency_code          2788 non-null   object
#  2   agency_jurisdiction  2788 non-null   object
#  3   population           2760 non-null   float64
#  4   violent_crimes       2753 non-null   float64
#  5   homicides            2754 non-null   float64
#  6   rapes                2754 non-null   float64
#  7   assaults             2753 non-null   float64
#  8   robberies            2754 non-null   float64
#  9   months_reported      2692 non-null   float64
#  10  crimes_percapita     2753 non-null   float64
#  11  homicides_percapita  2754 non-null   float64
#  12  rapes_percapita      2754 non-null   float64
#  13  assaults_percapita   2753 non-null   float64
#  14  robberies_percapita  2754 non-null   float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 326.8+ KB

# %%
us_df.isnull().sum()
# Out:
# report_year             0
# agency_code             0
# agency_jurisdiction     0
# population             28
# violent_crimes         35
# homicides              34
# rapes                  34
# assaults               35
# robberies              34
# months_reported        96
# crimes_percapita       35
# homicides_percapita    34
# rapes_percapita        34
# assaults_percapita     35
# robberies_percapita    34
# dtype: int64

# %%
us_df.dropna(subset=["agency_code","population","violent_crimes","homicides","rapes","assaults","robberies","months_reported","crimes_percapita","homicides_percapita","rapes_percapita","assaults_percapita","robberies_percapita"],inplace=True)
us_df
# Out:
#       report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 0            1975     NM00101     Albuquerque, NM    286238.0          2383.0
# 1            1976     NM00101     Albuquerque, NM    292265.0          2420.0
# 2            1977     NM00101     Albuquerque, NM    292341.0          2390.0
# 3            1978     NM00101     Albuquerque, NM    291834.0          2434.0
# 4            1979     NM00101     Albuquerque, NM    302120.0          2679.0
# ...           ...         ...                 ...         ...             ...
# 2782         2010     KS08703         Wichita, KS    382368.0          3038.0
# 2783         2011     KS08703         Wichita, KS    384796.0          2963.0
# 2784         2012     KS08703         Wichita, KS    386409.0          2896.0
# 2785         2013     KS08703         Wichita, KS    386486.0          3069.0
# 2786         2014     KS08703         Wichita, KS    387493.0          2939.0
#
#       homicides  rapes  assaults  robberies  months_reported  \
# 0          30.0  181.0    1353.0      819.0             12.0
# 1          28.0  186.0    1335.0      871.0             12.0
# 2          31.0  207.0    1398.0      754.0             12.0
# 3          37.0  187.0    1516.0      694.0             12.0
# 4          47.0  215.0    1602.0      815.0             12.0
# ...         ...    ...       ...        ...              ...
# 2782       16.0  251.0    2290.0      481.0             12.0
# 2783       25.0  245.0    2203.0      490.0             12.0
# 2784       23.0  242.0    2135.0      496.0             12.0
# 2785       15.0  250.0    2337.0      467.0             12.0
# 2786       21.0  243.0    2179.0      496.0             12.0
#
#       crimes_percapita  homicides_percapita  rapes_percapita  \
# 0               832.52                10.48            63.23
# 1               828.02                 9.58            63.64
# 2               817.54                10.60            70.81
# 3               834.04                12.68            64.08
# 4               886.73                15.56            71.16
# ...                ...                  ...              ...
# 2782            794.52                 4.18            65.64
# 2783            770.02                 6.50            63.67
# 2784            749.46                 5.95            62.63
# 2785            794.08                 3.88            64.69
# 2786            758.47                 5.42            62.71
#
#       assaults_percapita  robberies_percapita
# 0                 472.68               286.13
# 1                 456.78               298.02
# 2                 478.21               257.92
# 3                 519.47               237.81
# 4                 530.25               269.76
# ...                  ...                  ...
# 2782              598.90               125.80
# 2783              572.51               127.34
# 2784              552.52               128.36
# 2785              604.68               120.83
# 2786              562.33               128.00
#
# [2688 rows x 15 columns]

# %%
us_df.isnull().sum()
# Out:
# report_year            0
# agency_code            0
# agency_jurisdiction    0
# population             0
# violent_crimes         0
# homicides              0
# rapes                  0
# assaults               0
# robberies              0
# months_reported        0
# crimes_percapita       0
# homicides_percapita    0
# rapes_percapita        0
# assaults_percapita     0
# robberies_percapita    0
# dtype: int64

# %%
cols=["violent_crimes","homicides","rapes","assaults","robberies"]
us_df["total_crime"]=us_df[cols].sum(axis=1)
us_df
# Out:
#       report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 0            1975     NM00101     Albuquerque, NM    286238.0          2383.0
# 1            1976     NM00101     Albuquerque, NM    292265.0          2420.0
# 2            1977     NM00101     Albuquerque, NM    292341.0          2390.0
# 3            1978     NM00101     Albuquerque, NM    291834.0          2434.0
# 4            1979     NM00101     Albuquerque, NM    302120.0          2679.0
# ...           ...         ...                 ...         ...             ...
# 2782         2010     KS08703         Wichita, KS    382368.0          3038.0
# 2783         2011     KS08703         Wichita, KS    384796.0          2963.0
# 2784         2012     KS08703         Wichita, KS    386409.0          2896.0
# 2785         2013     KS08703         Wichita, KS    386486.0          3069.0
# 2786         2014     KS08703         Wichita, KS    387493.0          2939.0
#
#       homicides  rapes  assaults  robberies  months_reported  \
# 0          30.0  181.0    1353.0      819.0             12.0
# 1          28.0  186.0    1335.0      871.0             12.0
# 2          31.0  207.0    1398.0      754.0             12.0
# 3          37.0  187.0    1516.0      694.0             12.0
# 4          47.0  215.0    1602.0      815.0             12.0
# ...         ...    ...       ...        ...              ...
# 2782       16.0  251.0    2290.0      481.0             12.0
# 2783       25.0  245.0    2203.0      490.0             12.0
# 2784       23.0  242.0    2135.0      496.0             12.0
# 2785       15.0  250.0    2337.0      467.0             12.0
# 2786       21.0  243.0    2179.0      496.0             12.0
#
#       crimes_percapita  homicides_percapita  rapes_percapita  \
# 0               832.52                10.48            63.23
# 1               828.02                 9.58            63.64
# 2               817.54                10.60            70.81
# 3               834.04                12.68            64.08
# 4               886.73                15.56            71.16
# ...                ...                  ...              ...
# 2782            794.52                 4.18            65.64
# 2783            770.02                 6.50            63.67
# 2784            749.46                 5.95            62.63
# 2785            794.08                 3.88            64.69
# 2786            758.47                 5.42            62.71
#
#       assaults_percapita  robberies_percapita  total_crime
# 0                 472.68               286.13       4766.0
# 1                 456.78               298.02       4840.0
# 2                 478.21               257.92       4780.0
# 3                 519.47               237.81       4868.0
# 4                 530.25               269.76       5358.0
# ...                  ...                  ...          ...
# 2782              598.90               125.80       6076.0
# 2783              572.51               127.34       5926.0
# 2784              552.52               128.36       5792.0
# 2785              604.68               120.83       6138.0
# 2786              562.33               128.00       5878.0
#
# [2688 rows x 16 columns]

# %%
cols1=["crimes_percapita","homicides_percapita","rapes_percapita","assaults_percapita","robberies_percapita"]
us_df["total_crime_percapita"]=us_df[cols1].sum(axis=1)
us_df
# Out:
#       report_year agency_code agency_jurisdiction  population  violent_crimes  \
# 0            1975     NM00101     Albuquerque, NM    286238.0          2383.0
# 1            1976     NM00101     Albuquerque, NM    292265.0          2420.0
# 2            1977     NM00101     Albuquerque, NM    292341.0          2390.0
# 3            1978     NM00101     Albuquerque, NM    291834.0          2434.0
# 4            1979     NM00101     Albuquerque, NM    302120.0          2679.0
# ...           ...         ...                 ...         ...             ...
# 2782         2010     KS08703         Wichita, KS    382368.0          3038.0
# 2783         2011     KS08703         Wichita, KS    384796.0          2963.0
# 2784         2012     KS08703         Wichita, KS    386409.0          2896.0
# 2785         2013     KS08703         Wichita, KS    386486.0          3069.0
# 2786         2014     KS08703         Wichita, KS    387493.0          2939.0
#
#       homicides  rapes  assaults  robberies  months_reported  \
# 0          30.0  181.0    1353.0      819.0             12.0
# 1          28.0  186.0    1335.0      871.0             12.0
# 2          31.0  207.0    1398.0      754.0             12.0
# 3          37.0  187.0    1516.0      694.0             12.0
# 4          47.0  215.0    1602.0      815.0             12.0
# ...         ...    ...       ...        ...              ...
# 2782       16.0  251.0    2290.0      481.0             12.0
# 2783       25.0  245.0    2203.0      490.0             12.0
# 2784       23.0  242.0    2135.0      496.0             12.0
# 2785       15.0  250.0    2337.0      467.0             12.0
# 2786       21.0  243.0    2179.0      496.0             12.0
#
#       crimes_percapita  homicides_percapita  rapes_percapita  \
# 0               832.52                10.48            63.23
# 1               828.02                 9.58            63.64
# 2               817.54                10.60            70.81
# 3               834.04                12.68            64.08
# 4               886.73                15.56            71.16
# ...                ...                  ...              ...
# 2782            794.52                 4.18            65.64
# 2783            770.02                 6.50            63.67
# 2784            749.46                 5.95            62.63
# 2785            794.08                 3.88            64.69
# 2786            758.47                 5.42            62.71
#
#       assaults_percapita  robberies_percapita  total_crime  \
# 0                 472.68               286.13       4766.0
# 1                 456.78               298.02       4840.0
# 2                 478.21               257.92       4780.0
# 3                 519.47               237.81       4868.0
# 4                 530.25               269.76       5358.0
# ...                  ...                  ...          ...
# 2782              598.90               125.80       6076.0
# 2783              572.51               127.34       5926.0
# 2784              552.52               128.36       5792.0
# 2785              604.68               120.83       6138.0
# 2786              562.33               128.00       5878.0
#
#       total_crime_percapita
# 0                   1665.04
# 1                   1656.04
# 2                   1635.08
# 3                   1668.08
# 4                   1773.46
# ...                     ...
# 2782                1589.04
# 2783                1540.04
# 2784                1498.92
# 2785                1588.16
# 2786                1516.93
#
# [2688 rows x 17 columns]

# %%
h= us_df.groupby(['agency_jurisdiction'])['total_crime'].sum().sort_values(ascending=False).to_frame().reset_index()
h
u=h.nlargest(5,"total_crime")
u
# Out:
#   agency_jurisdiction  total_crime
# 0   New York City, NY    8426392.0
# 1     Los Angeles, CA    3908020.0
# 2         Chicago, IL    3872446.0
# 3         Detroit, MI    1812314.0
# 4         Houston, TX    1595090.0

# %%
plt.figure(figsize=(10,5))
plt.ticklabel_format(style='plain')
sns.barplot(x="agency_jurisdiction",y="total_crime",data=u)
plt.title('Maximum no.of crimes')
plt.xticks(rotation=45)

plt.show()

# %%
i= us_df.groupby(['agency_jurisdiction'])['population'].sum().sort_values(ascending=False).to_frame().reset_index()
i
# Out:
#    agency_jurisdiction   population
# 0    New York City, NY  305226678.0
# 1      Los Angeles, CA  139021793.0
# 2          Chicago, IL  115738403.0
# 3          Houston, TX   73757835.0
# 4     Philadelphia, PA   63983569.0
# ..                 ...          ...
# 63         Raleigh, NC   10169380.0
# 64          Aurora, CO    9715112.0
# 65      Louisville, KY    7723954.0
# 66         Orlando, FL    7137139.0
# 67  Salt Lake City, UT    7083662.0
#
# [68 rows x 2 columns]

# %%
j= us_df.groupby(['agency_jurisdiction'])['total_crime_percapita'].sum().sort_values(ascending=False).to_frame().reset_index()
j
tt=j.nlargest(5,'total_crime_percapita')
tt
# Out:
#   agency_jurisdiction  total_crime_percapita
# 0         Atlanta, GA              196686.63
# 1           Miami, FL              190386.12
# 2       St. Louis, MO              189021.82
# 3          Newark, NJ              181274.04
# 4         Detroit, MI              178396.54

# %%
k=pd.merge(h,i,how="inner")
k
k["total_crime_%"]=k["total_crime"]/k["population"]*100
hh=k.nlargest(5,"total_crime_%")
hh
# Out:
#    agency_jurisdiction  total_crime  population  total_crime_%
# 10         Atlanta, GA     847734.0  17554499.0       4.829155
# 15           Miami, FL     717940.0  15220089.0       4.717055
# 13       St. Louis, MO     748326.0  15890276.0       4.709333
# 24          Newark, NJ     541364.0  11852045.0       4.567684
# 3          Detroit, MI    1812314.0  40762796.0       4.446000

# %%
plt.subplot(1,2,1)
plt.bar(tt["agency_jurisdiction"],tt["total_crime_percapita"],color='g')
plt.title('Maximum no.of crimes per capita in us')
plt.xticks(rotation=45)
plt.subplot(1,2,2)
plt.pie(hh["total_crime_%"],labels=hh["agency_jurisdiction"],autopct='%0.0f%%')
plt.title('Maximum % of crimes in us')
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# # FROM ABOVE 1st GRAPH WE COULD FIND THAT "NEWYORK" HAVE MAXIMUM NUMBER OF CRIMES IN U.S, BUT AFTER ANALYSING CRIMES PER CAPITA AND ITS PERCENTAGE WE COULD SAY THAT "Atlanta, GA" WITH 20.8% HAVE THE MAXIMUM NO.OF CRIMES IN U.S.

# %%
cols3=pd.read_csv("C:\\Users\\Mahesh\\Desktop\\pravesh\\project\\crime analysis on us\\report.csv",usecols=["report_year","agency_jurisdiction","violent_crimes","homicides","rapes","assaults","robberies"])
cols3
# Out:
#       report_year agency_jurisdiction  violent_crimes  homicides  rapes  \
# 0            1975     Albuquerque, NM          2383.0       30.0  181.0
# 1            1976     Albuquerque, NM          2420.0       28.0  186.0
# 2            1977     Albuquerque, NM          2390.0       31.0  207.0
# 3            1978     Albuquerque, NM          2434.0       37.0  187.0
# 4            1979     Albuquerque, NM          2679.0       47.0  215.0
# ...           ...                 ...             ...        ...    ...
# 2783         2011         Wichita, KS          2963.0       25.0  245.0
# 2784         2012         Wichita, KS          2896.0       23.0  242.0
# 2785         2013         Wichita, KS          3069.0       15.0  250.0
# 2786         2014         Wichita, KS          2939.0       21.0  243.0
# 2787         2015         Wichita, KS          3839.0       27.0  349.0
#
#       assaults  robberies
# 0       1353.0      819.0
# 1       1335.0      871.0
# 2       1398.0      754.0
# 3       1516.0      694.0
# 4       1602.0      815.0
# ...        ...        ...
# 2783    2203.0      490.0
# 2784    2135.0      496.0
# 2785    2337.0      467.0
# 2786    2179.0      496.0
# 2787    2730.0      733.0
#
# [2788 rows x 7 columns]

# %%
g= cols3.groupby(['report_year'])
w=g['violent_crimes','homicides','rapes','assaults','robberies'].sum().reset_index()
w
# Out:
# C:\Users\Mahesh\AppData\Local\Temp\ipykernel_6384\213005889.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   w=g['violent_crimes','homicides','rapes','assaults','robberies'].sum().reset_index()
#     report_year  violent_crimes  homicides    rapes  assaults  robberies
# 0          1975        504007.0     9146.0  24357.0  179109.0   291395.0
# 1          1976        478701.0     8326.0  23928.0  178843.0   267604.0
# 2          1977        472588.0     8409.0  26356.0  186593.0   251230.0
# 3          1978        490348.0     8651.0  28148.0  197589.0   255960.0
# 4          1979        543347.0     9885.0  31494.0  215948.0   286020.0
# 5          1980        612318.0    10677.0  33002.0  228955.0   339684.0
# 6          1981        624032.0    10286.0  32042.0  223673.0   358031.0
# 7          1982        608323.0     9587.0  30681.0  228961.0   339094.0
# 8          1983        592416.0     9063.0  31800.0  232323.0   319230.0
# 9          1984        613527.0     8584.0  33679.0  262248.0   309016.0
# 10         1985        641493.0     8648.0  36204.0  281844.0   314797.0
# 11         1986        716491.0     9734.0  36736.0  330836.0   339185.0
# 12         1987        705834.0     9407.0  35221.0  343652.0   317554.0
# 13         1988        726439.0     9930.0  34588.0  361353.0   325627.0
# 14         1989        787135.0    10523.0  33592.0  388498.0   354522.0
# 15         1990        865969.0    11866.0  36541.0  419290.0   398272.0
# 16         1991        900316.0    12288.0  36058.0  430026.0   421944.0
# 17         1992        882124.0    11729.0  35249.0  432107.0   403039.0
# 18         1993        866963.0    11919.0  33328.0  431000.0   390716.0
# 19         1994        817446.0    10816.0  31375.0  420663.0   354592.0
# 20         1995        766751.0    10041.0  30041.0  402129.0   324540.0
# 21         1996        715249.0     8941.0  29340.0  380617.0   296351.0
# 22         1997        667270.0     7954.0  27730.0  367743.0   263843.0
# 23         1998        619280.0     7113.0  26494.0  351669.0   234004.0
# 24         1999        579433.0     6822.0  24679.0  330449.0   217483.0
# 25         2000        574377.0     6774.0  24552.0  329141.0   213910.0
# 26         2001        574528.0     7128.0  23934.0  326097.0   217369.0
# 27         2002        561665.0     7130.0  24305.0  317150.0   213080.0
# 28         2003        533396.0     7255.0  23461.0  294279.0   208401.0
# 29         2004        513157.0     6939.0  23174.0  286501.0   196543.0
# 30         2005        516126.0     7103.0  22746.0  281288.0   204989.0
# 31         2006        522223.0     7384.0  22190.0  278598.0   214051.0
# 32         2007        511135.0     7051.0  21141.0  272239.0   210704.0
# 33         2008        497761.0     6715.0  20160.0  264209.0   206677.0
# 34         2009        463986.0     5985.0  19895.0  249491.0   188615.0
# 35         2010        438261.0     5867.0  19660.0  241700.0   171034.0
# 36         2011        423978.0     5702.0  19573.0  232878.0   165825.0
# 37         2012        431738.0     5848.0  19709.0  239243.0   166938.0
# 38         2013        422507.0     5344.0  22739.0  230952.0   163472.0
# 39         2014        421311.0     5349.0  27107.0  237519.0   151336.0
# 40         2015        425427.0     6042.0  29423.0  239964.0   149998.0

# %%
w["max_crime"]=w[["violent_crimes","homicides","rapes","assaults","robberies"]].idxmax(axis=1)
w
n=w.nlargest(10,"violent_crimes")
n
# Out:
#     report_year  violent_crimes  homicides    rapes  assaults  robberies  \
# 16         1991        900316.0    12288.0  36058.0  430026.0   421944.0
# 17         1992        882124.0    11729.0  35249.0  432107.0   403039.0
# 18         1993        866963.0    11919.0  33328.0  431000.0   390716.0
# 15         1990        865969.0    11866.0  36541.0  419290.0   398272.0
# 19         1994        817446.0    10816.0  31375.0  420663.0   354592.0
# 14         1989        787135.0    10523.0  33592.0  388498.0   354522.0
# 20         1995        766751.0    10041.0  30041.0  402129.0   324540.0
# 13         1988        726439.0     9930.0  34588.0  361353.0   325627.0
# 11         1986        716491.0     9734.0  36736.0  330836.0   339185.0
# 21         1996        715249.0     8941.0  29340.0  380617.0   296351.0
#
#          max_crime
# 16  violent_crimes
# 17  violent_crimes
# 18  violent_crimes
# 15  violent_crimes
# 19  violent_crimes
# 14  violent_crimes
# 20  violent_crimes
# 13  violent_crimes
# 11  violent_crimes
# 21  violent_crimes

# %%
plt.figure(figsize=(10,5))
plt.ticklabel_format(style='plain')
sns.barplot(x="report_year",y="violent_crimes",data=n)
plt.title('Maximum no.of violent_cimes by year')
plt.xticks(rotation=45)


plt.show()

# %%
plt.subplot(1,2,1)
plt.hist(w["max_crime"],color="r")
plt.title("maximum crime among all other crime")
plt.subplot(1,2,2)
plt.pie(n["violent_crimes"],labels=n["report_year"],autopct='%0.2f%%')
plt.title("maximum violent crime in % by year")
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %%
t= cols3.groupby(['agency_jurisdiction'])
f=t['violent_crimes','homicides','rapes','assaults','robberies'].sum().reset_index()
f
# Out:
# C:\Users\Mahesh\AppData\Local\Temp\ipykernel_6384\4261342.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   f=t['violent_crimes','homicides','rapes','assaults','robberies'].sum().reset_index()
#    agency_jurisdiction  violent_crimes  homicides    rapes  assaults  \
# 0      Albuquerque, NM        181182.0     1722.0  10737.0  118638.0
# 1        Arlington, TX         68281.0      542.0   5024.0   42280.0
# 2          Atlanta, GA        429070.0     6249.0  17134.0  234928.0
# 3           Aurora, CO         77607.0      594.0   6485.0   51435.0
# 4           Austin, TX        115611.0     1456.0  11388.0   59057.0
# ..                 ...             ...        ...      ...       ...
# 63          Tucson, AZ        152317.0     1619.0  11029.0   95177.0
# 64           Tulsa, OK        155436.0     1737.0  11066.0  103086.0
# 65  Virginia Beach, VA         34042.0      679.0   4218.0   13385.0
# 66      Washington, DC        433937.0     9889.0  12195.0  187757.0
# 67         Wichita, KS         93498.0     1098.0   9011.0   54158.0
#
#     robberies
# 0     50085.0
# 1     20435.0
# 2    170759.0
# 3     19093.0
# 4     43710.0
# ..        ...
# 63    44492.0
# 64    39547.0
# 65    15760.0
# 66   224096.0
# 67    29231.0
#
# [68 rows x 6 columns]

# %%
f["crime"]=f[["violent_crimes","homicides","rapes","assaults","robberies"]].idxmax(axis=1)
f
s=f.nlargest(10,"violent_crimes")
s
# Out:
#       agency_jurisdiction  violent_crimes  homicides     rapes   assaults  \
# 41      New York City, NY       4263284.0    47176.0  101795.0  1788065.0
# 29        Los Angeles, CA       1979166.0    25999.0   69748.0  1027731.0
# 10            Chicago, IL       1960886.0    27727.0   90209.0   951805.0
# 16            Detroit, MI        918003.0    19497.0   40857.0   420940.0
# 22            Houston, TX        819539.0    15179.0   40207.0   367276.0
# 47       Philadelphia, PA        763201.0    14590.0   37318.0   302326.0
# 6           Baltimore, MD        600630.0    10573.0   17990.0   276239.0
# 14             Dallas, TX        590468.0    10388.0   33708.0   286148.0
# 34  Miami-Dade County, FL        500061.0     5409.0   21028.0   302554.0
# 66         Washington, DC        433937.0     9889.0   12195.0   187757.0
#
#     robberies           crime
# 41  2326248.0  violent_crimes
# 29   855688.0  violent_crimes
# 10   891145.0  violent_crimes
# 16   436709.0  violent_crimes
# 22   396877.0  violent_crimes
# 47   408967.0  violent_crimes
# 6    295828.0  violent_crimes
# 14   260224.0  violent_crimes
# 34   171070.0  violent_crimes
# 66   224096.0  violent_crimes

# %%
plt.figure(figsize=(10,5))
plt.ticklabel_format(style='plain')
sns.barplot(x="agency_jurisdiction",y="violent_crimes",data=s)
plt.title('Maximum no.of violent_cimes by year')
plt.xticks(rotation=45)


plt.show()

# %%
plt.subplot(1,2,1)
plt.hist(f["crime"],color="r")
plt.title("maximum crime among all other crime")
plt.subplot(1,2,2)
plt.pie(s["violent_crimes"],labels=s["agency_jurisdiction"],radius=1,autopct='%0.2f%%')
plt.title("maximum violent crime in % by city")
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()

# %% [markdown]
# # AFTER ANALYSING THE DATA BY YEAR AND CITY, IT IS FOUND THAT "VIOLENT CRIME" IS MORE COMPARING WITH ALL OTHER CRIMES, WHICH CAN BE SEEN BY ABOVE TWO HISTOGRAM,i.e MAXIMUM CRIME AMONG ALL OTHER CRIME. ALSO, IT IS FOUND THAT,IN THE YEAR "1992" WITH 10.92% AND CITY "NEWYORK" WITH 33.23% HAVE THE MAXIMUM VIOLENT CRIMES IN US, WHICH CAN BE SEEN ABOVE BAR AND PIE CHART.
